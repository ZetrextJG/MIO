# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_train = pd.read_csv("../mio1/regression/square-simple-training.csv")
df_test = pd.read_csv("../mio1/regression/steps-large-test.csv")

X_train = df_train["x"].values
y_train = df_train["y"].values

X_test = df_test["x"].values
y_test = df_test["y"].values

# %%
plt.plot(X_train, y_train, 'ro', label='train')
plt.title("Wizualizacja danych treningowych zbioru square-simple")
# Out:
# Text(0.5, 1.0, 'Wizualizacja danych treningowych zbioru square-simple')
